# %% [markdown]
# # **Creació dels dataframes inicials**

# %% [markdown]
# ## Mount drive

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
# %cd {'/content/drive/MyDrive/TFG'}
# Out:
# /content/drive/MyDrive/TFG

# %% [markdown]
# ## Llibreries

# %%
import os #per manipular estructura directoris
import datetime #per els temps del sistema
import matplotlib.pyplot as plt #per fer els grafics
import math
import numpy as np
import pandas as pd

# %% [markdown]
# ## Usuaris a estudiar

# %%
users = []
u_nofalls = []
u_falls = []
for folder in os.listdir('data'): #documents que hi han en la carpeta data
  u = str('data/'+ str(folder))
  if os.path.isdir(u): #mirar si és una carpeta
    if os.listdir(u): #mira si hi ha contingut
      users.append(int(folder)) #si en té, volem estudiar aquest usuari
      if os.path.exists(str(str(u)+'/Falls.txt')):
        u_falls.append(int(folder))
      else:
        u_nofalls.append(int(folder))
users.sort()
u_falls.sort()
u_nofalls.sort()
for i in [4,10]: #eliminar dos usuaris que sabem no tenen totes les dades
  users.remove(i)
  u_nofalls.remove(i)
tot_users = len(users)
num_users_nofalls = len(u_nofalls)
num_users_falls = len(u_falls)

print("Usuaris a estudiar:")
print(users)
print("Usuaris a estudiar que han caigut:")
print(u_falls)
print("Usuaris a estudiar que no han caigut:")
print(u_nofalls)
# Out:
# Usuaris a estudiar:
# [17, 20, 33, 34, 36, 40, 42, 44, 45, 46, 48, 49, 50, 51, 54, 55, 56, 59, 60, 61, 62, 63, 64, 66, 67, 69, 70, 73, 74, 75, 76, 78, 79, 80, 81, 82, 83, 84, 85, 88, 89, 90, 91, 92, 95, 96, 98, 100, 101, 102, 103]
# Usuaris a estudiar que han caigut:
# [17, 20, 51, 59, 61, 62, 63, 64, 78, 81, 83, 85, 88, 89, 90, 91, 92, 100, 102, 103]
# Usuaris a estudiar que no han caigut:
# [33, 34, 36, 40, 42, 44, 45, 46, 48, 49, 50, 54, 55, 56, 60, 66, 67, 69, 70, 73, 74, 75, 76, 79, 80, 82, 84, 95, 96, 98, 101]

# %% [markdown]
# ## Usuaris i dates a estudiar

# %%
ruta_sortida = '/dates_estudiar.txt'
if os.path.isfile(ruta_sortida):
  os.remove(ruta_sortida)
for carpeta in users:
  directori = str('data/'+str(carpeta))
  arxius = os.listdir(directori) #arxius dins la carpeta
  fitxers_reg = [arxiu for arxiu in arxius if arxiu.startswith('reg_')] #arxius reg
  dates = [arxiu.split('_')[1].split('.')[0] for arxiu in fitxers_reg] # extreiem les dates
  text = ""
  for data in dates:
    text = text + data + ' ' + str(carpeta) +'\n'
  if not os.path.isfile(ruta_sortida): #mirem si existeix arxiu
    with open(ruta_sortida, 'w') as archivo: #com no existeix, el creem i afegim text
        archivo.write(text)
    print("S'ha creat l'arxiu:", ruta_sortida)
  else: #arxiu existeix
    with open(ruta_sortida, 'r') as archivo: #mirar si text esta ja escrit
        contenido = archivo.read()
    if text in contenido:
        print("El text ja està escrit a l'arxiu", ruta_sortida)
    else: # si no esta escrit, afegir el text
        with open(ruta_sortida, 'a') as archivo:
            archivo.write(text)
        print("S'han afegit les dates de la carpeta " + str(carpeta) + ' al arxiu:', ruta_sortida)
print("Les dates s'han guardat al arxiu:", ruta_sortida)
# Out:
# S'ha creat l'arxiu: /dates_estudiar.txt
# S'han afegit les dates de la carpeta 20 al arxiu: /dates_estudiar.txt
# S'han afegit les dates de la carpeta 33 al arxiu: /dates_estudiar.txt
# S'han afegit les dates de la carpeta 34 al arxiu: /dates_estudiar.txt
# S'han afegit les dates de la carpeta 36 al arxiu: /dates_estudiar.txt
# S'han afegit les dates de la carpeta 40 al arxiu: /dates_estudiar.txt
# S'han afegit les dates de la carpeta 42 al arxiu: /dates_estudiar.txt
# S'han afegit les dates de la carpeta 44 al arxiu: /dates_estudiar.txt
# S'han afegit les dates de la carpeta 45 al arxiu: /dates_estudiar.txt
# S'han afegit les dates de la carpeta 46 al arxiu: /dates_estudiar.txt
# S'han afegit les dates de la carpeta 48 al arxiu: /dates_estudiar.txt
# S'han afegit les dates de la carpeta 49 al arxiu: /dates_estudiar.txt
# S'han afegit les dates de la carpeta 50 al arxiu: /dates_estudiar.txt
# S'han afegit les dates de la carpeta 51 al arxiu: /dates_estudiar.txt
# S'han afegit les dates de la carpeta 54 al arxiu: /dates_estudiar.txt
# S'han afegit les dates de la carpeta 55 al arxiu: /dates_estudiar.txt
# S'han afegit les dates de la carpeta 56 al arxiu: /dates_estudiar.txt
# S'han afegit les dates de la carpeta 59 al arxiu: /dates_estudiar.txt
# S'han afegit les dates de la carpeta 60 al arxiu: /dates_estudiar.txt
# S'han afegit les dates de la carpeta 61 al arxiu: /dates_estudiar.txt
# S'han afegit les dates de la carpeta 62 al arxiu: /dates_estudiar.txt
# S'han afegit les dates de la carpeta 63 al arxiu: /dates_estudiar.txt
# S'han afegit les dates de la carpeta 64 al arxiu: /dates_estudiar.txt
# S'han afegit les dates de la carpeta 66 al arxiu: /dates_estudiar.txt
# S'han afegit les dates de la carpeta 67 al arxiu: /dates_estudiar.txt
# S'han afegit les dates de la carpeta 69 al arxiu: /dates_estudiar.txt
# S'han afegit les dates de la carpeta 70 al arxiu: /dates_estudiar.txt
# S'han afegit les dates de la carpeta 73 al arxiu: /dates_estudiar.txt
# S'han afegit les dates de la carpeta 74 al arxiu: /dates_estudiar.txt
# S'han afegit les dates de la carpeta 75 al arxiu: /dates_estudiar.txt
# S'han afegit les dates de la carpeta 76 al arxiu: /dates_estudiar.txt
# S'han afegit les dates de la carpeta 78 al arxiu: /dates_estudiar.txt
# S'han afegit les dates de la carpeta 79 al arxiu: /dates_estudiar.txt
# S'han afegit les dates de la carpeta 80 al arxiu: /dates_estudiar.txt
# S'han afegit les dates de la carpeta 81 al arxiu: /dates_estudiar.txt
# S'han afegit les dates de la carpeta 82 al arxiu: /dates_estudiar.txt
# S'han afegit les dates de la carpeta 83 al arxiu: /dates_estudiar.txt
# S'han afegit les dates de la carpeta 84 al arxiu: /dates_estudiar.txt
# S'han afegit les dates de la carpeta 85 al arxiu: /dates_estudiar.txt
# S'han afegit les dates de la carpeta 88 al arxiu: /dates_estudiar.txt
# S'han afegit les dates de la carpeta 89 al arxiu: /dates_estudiar.txt
# S'han afegit les dates de la carpeta 90 al arxiu: /dates_estudiar.txt
# S'han afegit les dates de la carpeta 91 al arxiu: /dates_estudiar.txt
# S'han afegit les dates de la carpeta 92 al arxiu: /dates_estudiar.txt
# S'han afegit les dates de la carpeta 95 al arxiu: /dates_estudiar.txt
# S'han afegit les dates de la carpeta 96 al arxiu: /dates_estudiar.txt
# S'han afegit les dates de la carpeta 98 al arxiu: /dates_estudiar.txt
# S'han afegit les dates de la carpeta 100 al arxiu: /dates_estudiar.txt
# S'han afegit les dates de la carpeta 101 al arxiu: /dates_estudiar.txt
# S'han afegit les dates de la carpeta 102 al arxiu: /dates_estudiar.txt
# S'han afegit les dates de la carpeta 103 al arxiu: /dates_estudiar.txt
# Les dates s'han guardat al arxiu: /dates_estudiar.txt

# %%
with open(ruta_sortida, 'r') as arxiu:
    lineas = arxiu.readlines()
    lineas_filtradas = [linea for linea in lineas if not linea.startswith("right")]
with open(ruta_sortida, 'w') as archivo:
    archivo.writelines(lineas_filtradas)

with open(ruta_sortida, 'r') as arxiu:
    text = arxiu.read()
print("Contingut de l'arxiu:")
print(text)
# Out:
# Contingut de l'arxiu:
# 11-09-2014 17
# 18-09-2014 17
# 15-10-2014 17
# 24-10-2014 17
# 29-10-2014 17
# 12-11-2014 17
# 13-11-2014 17
# 09-12-2014 17
# 04-12-2014 17
# 03-12-2014 17
# 12-12-2014 17
# 17-12-2014 17
# 18-01-2015 17
# 30-01-2015 17
# 02-02-2015 17
# 04-02-2015 17
# 25-02-2015 17
# 03-03-2015 17
# 22-04-2015 17
# 17-04-2015 17
# 24-04-2015 17
# 04-05-2015 17
# 05-05-2015 17
# 09-05-2015 17
# 27-07-2015 17
# 01-04-2015 17
# 16-09-2014 20
# 18-09-2014 20
# 19-09-2014 20
# 22-09-2014 20
# 23-09-2014 20
# 24-09-2014 20
# 01-10-2014 20
# 03-10-2014 20
# 06-10-2014 20
# 07-10-2014 20
# 08-10-2014 20
# 09-10-2014 20
# 14-10-2014 20
# 22-10-2014 20
# 23-10-2014 20
# 31-10-2014 20
# 03-11-2014 20
# 06-11-2014 20
# 04-11-2014 20
# 05-11-2014 20
# 17-11-2014 20
# 19-11-2014 20
# 21-11-2014 20
# 24-11-2014 20
# 25-11-2014 20
# 01-12-2014 20
# 02-12-2014 20
# 03-12-2014 20
# 04-12-2014 20
# 09-12-2014 20
# 12-12-2014 20
# 08-01-2015 20
# 06-02-2015 20
# 17-12-2014 20
# 15-12-2014 20
# 15-12-2014 20
# 15-12-2014 20
# 14-03-2015 20
# 13-03-2015 20
# 03-03-2015 20
# 16-03-2015 20
# 06-03-2015 20
# 17-03-2015 20
# 11-03-2015 20
# 12-03-2015 20
# 27-02-2015 20
# 18-03-2015 20
# 30-03-2015 20
# 31-03-2015 20
# 07-04-2015 20
# 08-04-2015 20
# 01-07-2015 20
# 06-09-2016 20
# 07-09-2016 20
# 18-01-2017 20
# 19-01-2017 20
# 22-09-2016 20
# 14-10-2016 20
# 09-10-2014 33
# 10-10-2014 33
# 11-10-2014 33
# 12-10-2014 33
# 14-10-2014 33
# 15-10-2014 33
# 02-10-2014 33
# 20-10-2014 33
# 21-10-2014 33
# 16-10-2014 33
# 11-09-2014 34
# 13-09-2014 34
# 14-09-2014 34
# 12-09-2014 34
# 17-09-2014 34
# 15-10-2014 34
# 17-10-2014 34
# 16-10-2014 34
# 06-11-2014 34
# 18-11-2014 34
# 21-09-2014 36
# 23-09-2014 36
# 18-09-2014 36
# 20-09-2014 36
# 19-09-2014 36
# 24-09-2014 36
# 25-09-2014 40
# 26-09-2014 40
# 24-09-2014 40
# 02-10-2014 42
# 04-10-2014 42
# 03-10-2014 42
# 07-11-2014 42
# 13-10-2014 44
# 10-10-2014 44
# 14-10-2014 44
# 15-10-2014 44
# 15-10-2014 45
# 16-10-2014 45
# 17-10-2014 45
# 18-10-2014 45
# 17-10-2014 46
# 20-10-2014 46
# 22-10-2014 46
# 08-11-2015 48
# 08-11-2021 48
# 10-11-2014 48
# 08-11-2014 48
# 01-11-2014 48
# 06-11-2014 48
# 05-11-2014 48
# 31-10-2014 48
# 09-11-2014 48
# 07-11-2014 48
# 13-11-2014 48
# 14-11-2014 48
# 15-11-2014 48
# 22-10-2014 49
# 17-10-2014 49
# 23-10-2014 49
# 24-10-2014 49
# 25-10-2014 49
# 23-10-2014 50
# 25-10-2014 50
# 27-10-2014 50
# 26-10-2014 50
# 29-10-2014 50
# 30-10-2014 50
# 30-10-2014 51
# 28-10-2014 51
# 27-10-2014 51
# 15-12-2014 51
# 07-12-2014 51
# 16-12-2014 51
# 17-12-2014 51
# 18-12-2014 51
# 19-12-2014 51
# 20-12-2014 51
# 21-12-2014 51
# 22-12-2014 51
# 23-12-2014 51
# 25-12-2014 51
# 26-12-2014 51
# 27-12-2014 51
# 28-12-2014 51
# 29-12-2014 51
# 30-12-2014 51
# 13-01-2015 51
# 02-01-1970 51
# 09-11-2014 54
# 12-11-2014 54
# 14-11-2014 54
# 15-11-2014 54
# 18-11-2014 54
# 19-11-2014 54
# 23-11-2014 54
# 24-11-2014 54
# 28-11-2014 54
# 09-11-2014 55
# 05-12-2014 56
# 11-12-2014 56
# 10-12-2014 56
# 06-12-2014 56
# 19-11-2014 59
# 22-11-2014 59
# 21-11-2014 59
# 20-11-2014 59
# 01-12-2014 59
# 28-11-2014 59
# 02-12-2014 59
# 30-11-2014 59
# 27-11-2014 59
# 29-11-2014 59
# 23-11-2014 59
# 11-02-2015 59
# 16-02-2015 59
# 18-02-2015 59
# 19-02-2015 59
# 25-02-2015 59
# 26-02-2015 59
# 04-05-2015 59
# 05-05-2015 59
# 07-05-2015 59
# 11-05-2015 59
# 28-07-2015 59
# 29-07-2015 59
# 13-11-2015 59
# 17-11-2015 59
# 26-11-2015 59
# 03-12-2015 59
# 04-12-2015 59
# 09-12-2015 59
# 11-12-2015 59
# 19-11-2015 59
# 20-11-2015 59
# 27-11-2015 59
# 25-11-2014 60
# 27-11-2014 60
# 20-11-2014 60
# 24-11-2014 60
# 23-11-2014 60
# 22-11-2014 60
# 21-11-2014 60
# 19-11-2014 60
# 25-11-2014 61
# 26-11-2014 61
# 27-11-2014 61
# 23-11-2014 61
# 22-11-2014 61
# 19-11-2014 61
# 21-11-2014 61
# 20-11-2014 61
# 24-11-2014 62
# 26-11-2014 62
# 25-11-2014 62
# 27-11-2014 62
# 30-11-2014 62
# 29-11-2014 62
# 01-12-2014 62
# 03-12-2014 62
# 04-12-2014 62
# 26-02-2015 62
# 24-11-2014 63
# 02-12-2014 63
# 04-12-2014 63
# 03-12-2014 63
# 24-11-2014 64
# 25-11-2014 64
# 03-12-2014 64
# 02-12-2014 64
# 04-12-2014 64
# 06-12-2014 64
# 24-02-2015 64
# 26-02-2015 64
# 20-02-2015 64
# 07-12-2014 64
# 27-11-2014 66
# 28-11-2014 66
# 21-11-2014 66
# 25-11-2014 66
# 29-11-2014 66
# 09-12-2014 66
# 22-11-2014 66
# 05-12-2014 66
# 04-12-2014 66
# 30-11-2014 66
# 03-12-2014 66
# 02-12-2014 66
# 01-12-2014 66
# 05-12-2014 67
# 30-11-2014 67
# 20-11-2014 67
# 27-11-2014 67
# 28-11-2014 67
# 09-12-2014 69
# 20-12-2014 69
# 12-12-2014 69
# 13-12-2014 69
# 16-12-2014 69
# 17-12-2014 69
# 15-12-2014 69
# 08-12-2014 69
# 18-12-2014 69
# 19-12-2014 69
# 07-12-2014 70
# 08-12-2014 73
# 08-12-2014 74
# 08-12-2014 75
# 08-12-2014 76
# 15-12-2014 78
# 16-12-2014 78
# 17-12-2014 78
# 13-12-2014 78
# 14-12-2014 78
# 10-12-2014 78
# 11-12-2014 78
# 05-12-2014 78
# 24-11-2014 78
# 21-11-2014 78
# 27-11-2014 78
# 19-11-2014 78
# 28-11-2014 78
# 06-12-2014 78
# 09-12-2014 78
# 22-11-2014 78
# 23-11-2014 78
# 12-12-2014 78
# 03-02-2015 78
# 11-02-2015 78
# 17-12-2014 79
# 04-02-2015 79
# 12-12-2014 79
# 15-12-2014 79
# 10-12-2014 79
# 16-12-2014 79
# 11-12-2014 79
# 01-12-2014 80
# 10-12-2014 80
# 12-12-2014 80
# 13-12-2014 80
# 11-12-2014 80
# 17-12-2014 81
# 05-02-2015 81
# 09-02-2015 81
# 12-02-2015 81
# 11-02-2015 81
# 08-02-2015 81
# 07-02-2015 81
# 06-02-2015 81
# 10-02-2015 81
# 25-02-2015 81
# 15-12-2014 81
# 09-12-2014 81
# 13-12-2014 81
# 10-12-2014 81
# 11-12-2014 81
# 16-12-2014 81
# 12-12-2014 81
# 11-12-2014 82
# 31-12-2014 83
# 29-12-2014 83
# 25-12-2014 83
# 24-12-2014 83
# 17-12-2014 83
# 16-12-2014 83
# 14-12-2014 83
# 15-12-2014 83
# 14-12-2014 84
# 21-12-2014 84
# 23-12-2014 84
# 31-12-2014 84
# 30-12-2014 84
# 22-12-2014 84
# 01-01-2015 84
# 29-12-2014 84
# 04-12-2014 85
# 03-12-2014 85
# 23-12-2014 85
# 22-12-2014 85
# 26-12-2014 85
# 27-12-2014 85
# 25-12-2014 85
# 28-12-2014 85
# 29-12-2014 85
# 30-12-2014 85
# 31-12-2014 85
# 02-01-2015 85
# 08-01-2015 85
# 18-01-2015 85
# 20-02-2015 85
# 15-02-2015 85
# 23-01-2015 85
# 24-12-2014 85
# 23-12-2014 88
# 25-12-2014 88
# 27-12-2014 88
# 26-12-2014 88
# 24-12-2014 88
# 11-12-2014 88
# 24-12-2014 89
# 28-12-2014 89
# 29-12-2014 89
# 27-12-2014 89
# 16-12-2014 89
# 14-12-2014 89
# 15-12-2014 89
# 17-12-2014 89
# 01-01-2015 90
# 02-01-2015 90
# 04-01-2015 90
# 29-12-2014 90
# 27-12-2014 90
# 13-01-2015 90
# 21-01-2015 91
# 28-01-2015 91
# 26-01-2015 91
# 25-01-2015 91
# 23-01-2015 91
# 24-01-2015 91
# 01-02-2015 91
# 02-02-2015 91
# 31-01-2015 91
# 30-01-2015 91
# 29-01-2015 91
# 22-01-2015 91
# 19-01-2015 92
# 20-01-2015 92
# 22-01-2015 92
# 21-01-2015 92
# 23-01-2015 92
# 24-01-2015 92
# 26-01-2015 92
# 27-01-2015 92
# 28-01-2015 92
# 29-01-2015 92
# 30-01-2015 92
# 01-02-2015 92
# 31-01-2015 92
# 02-02-2015 92
# 24-02-2015 92
# 14-02-2015 92
# 17-01-2015 95
# 15-01-2015 95
# 16-01-2015 95
# 23-01-2015 95
# 24-01-2015 95
# 31-01-2015 95
# 27-02-2015 95
# 13-02-2015 95
# 09-02-2015 95
# 10-02-2015 95
# 24-01-2015 96
# 01-02-2015 96
# 03-02-2015 96
# 08-02-2015 96
# 26-01-2015 96
# 28-01-2015 96
# 07-02-2015 96
# 29-01-2015 96
# 27-01-2015 96
# 18-02-2015 96
# 19-02-2015 96
# 26-02-2015 96
# 20-03-2015 96
# 21-03-2015 96
# 31-01-2015 98
# 30-01-2015 98
# 02-02-2015 98
# 29-01-2015 98
# 08-02-2015 100
# 03-02-2015 100
# 17-02-2015 100
# 19-02-2015 100
# 24-02-2015 100
# 26-02-2015 100
# 16-02-2015 100
# 16-02-2015 101
# 05-02-2015 102
# 09-02-2015 102
# 12-02-2015 102
# 11-02-2015 102
# 08-02-2015 102
# 10-02-2015 102
# 06-02-2015 102
# 11-02-2015 103
# 09-02-2015 103
# 26-02-2015 103
# 10-02-2015 103
# 24-02-2015 103
# 15-02-2015 103
# 25-02-2015 103
# 23-02-2015 103
# 19-02-2015 103
# 20-02-2015 103
# 22-02-2015 103
# 21-02-2015 103
# 18-02-2015 103
# 04-06-2015 103
# 08-07-2015 103
# 15-07-2015 103
# 14-10-2015 103
# 23-10-2015 103
# 28-10-2015 103
# 24-10-2015 103
# 25-10-2015 103
# 24-09-2016 103
# 22-11-2016 103
# 29-03-2014 103

# %%
def create_df(user,date):
  try:
    with open(str('data/'+ user + '/reg_' + date + '.txt'), 'r') as doc:
      lines = doc.readlines()

    timestamp_1 = []
    xyz_giroscopi_1 = []
    xyz_accelerometre1_1 = []
    xyz_accelerometre2_1 = []
    sensors_presio_1 = []
    temps_sistema_1 = []
    calibracio_1 = []
    timestamp_2 = []
    xyz_giroscopi_2 = []
    xyz_accelerometre1_2 = []
    xyz_accelerometre2_2 = []
    temps_sistema_2 = []
    sensors_presio_2 = []
    calibracio_2 = []

    for line in lines:
        values = line.strip().split(',')

        # Primera plantilla
        timestamp_1.append(int(values[0]))
        xyz_giroscopi_1.append([int(values[1]), int(values[2]), int(values[3])])
        xyz_accelerometre1_1.append([int(values[4]), int(values[5]), int(values[6])])
        xyz_accelerometre2_1.append([int(values[7]), int(values[8]), int(values[9])])
        sensors_presio_1.append([int(values[i]) for i in range(10, 24)])
        temps_sistema_1.append(int(values[24]))
        calibracio_1.append(int(values[25]))

        # Segona plantilla
        timestamp_2.append(int(values[26]))
        xyz_giroscopi_2.append([int(values[27]), int(values[28]), int(values[29])])
        xyz_accelerometre1_2.append([int(values[30]), int(values[31]), int(values[32])])
        xyz_accelerometre2_2.append([int(values[33]), int(values[34]), int(values[35])])
        sensors_presio_2.append([int(values[i]) for i in range(36, 50)])
        temps_sistema_2.append(int(values[50]))
        calibracio_2.append(int(values[51]))

    df = pd.DataFrame({
      'Usuari': user,
      'P1 timestamp': np.array(timestamp_1),
      'P1 giroscopi X': np.array([sublist[0] for sublist in xyz_giroscopi_1]),
      'P1 giroscopi Y': np.array([sublist[1] for sublist in xyz_giroscopi_1]),
      'P1 giroscopi Z': np.array([sublist[2] for sublist in xyz_giroscopi_1]),
      'P1 accelerometre 1X': np.array([sublist[0] for sublist in xyz_accelerometre1_1]),
      'P1 accelerometre 1Y': np.array([sublist[1] for sublist in xyz_accelerometre1_1]),
      'P1 accelerometre 1Z': np.array([sublist[2] for sublist in xyz_accelerometre1_1]),
      'P1 accelerometre 2X': np.array([sublist[0] for sublist in xyz_accelerometre2_1]),
      'P1 accelerometre 2Y': np.array([sublist[1] for sublist in xyz_accelerometre2_1]),
      'P1 accelerometre 2Z': np.array([sublist[2] for sublist in xyz_accelerometre2_1]),
      'P1 sensor pressió 1': np.array([sublist[0] for sublist in sensors_presio_1]),
      'P1 sensor pressió 2': np.array([sublist[1] for sublist in sensors_presio_1]),
      'P1 sensor pressió 3': np.array([sublist[2] for sublist in sensors_presio_1]),
      'P1 sensor pressió 4': np.array([sublist[3] for sublist in sensors_presio_1]),
      'P1 sensor pressió 5': np.array([sublist[4] for sublist in sensors_presio_1]),
      'P1 sensor pressió 6': np.array([sublist[5] for sublist in sensors_presio_1]),
      'P1 sensor pressió 7': np.array([sublist[6] for sublist in sensors_presio_1]),
      'P1 sensor pressió 8': np.array([sublist[7] for sublist in sensors_presio_1]),
      'P1 sensor pressió 9': np.array([sublist[8] for sublist in sensors_presio_1]),
      'P1 sensor pressió 10': np.array([sublist[9] for sublist in sensors_presio_1]),
      'P1 sensor pressió 11': np.array([sublist[10] for sublist in sensors_presio_1]),
      'P1 sensor pressió 12': np.array([sublist[11] for sublist in sensors_presio_1]),
      'P1 sensor pressió 13': np.array([sublist[12] for sublist in sensors_presio_1]),
      'P1 sensor pressió 14': np.array([sublist[13] for sublist in sensors_presio_1]),
      'P1 Temps Sistema': np.array(temps_sistema_1),
      'P1 Calibració': np.array(calibracio_1),
      #'Fall Labels': fall_labels.flatten()
      'P2 timestamp': np.array(timestamp_2),
      'P2 giroscopi X': np.array([sublist[0] for sublist in xyz_giroscopi_2]),
      'P2 giroscopi Y': np.array([sublist[1] for sublist in xyz_giroscopi_2]),
      'P2 giroscopi Z': np.array([sublist[2] for sublist in xyz_giroscopi_2]),
      'P2 accelerometre 1X': np.array([sublist[0] for sublist in xyz_accelerometre1_2]),
      'P2 accelerometre 1Y': np.array([sublist[1] for sublist in xyz_accelerometre1_2]),
      'P2 accelerometre 1Z': np.array([sublist[2] for sublist in xyz_accelerometre1_2]),
      'P2 accelerometre 2X': np.array([sublist[0] for sublist in xyz_accelerometre2_2]),
      'P2 accelerometre 2Y': np.array([sublist[1] for sublist in xyz_accelerometre2_2]),
      'P2 accelerometre 2Z': np.array([sublist[2] for sublist in xyz_accelerometre2_2]),
      'P2 sensor pressió 1': np.array([sublist[0] for sublist in sensors_presio_2]),
      'P2 sensor pressió 2': np.array([sublist[1] for sublist in sensors_presio_2]),
      'P2 sensor pressió 3': np.array([sublist[2] for sublist in sensors_presio_2]),
      'P2 sensor pressió 4': np.array([sublist[3] for sublist in sensors_presio_2]),
      'P2 sensor pressió 5': np.array([sublist[4] for sublist in sensors_presio_2]),
      'P2 sensor pressió 6': np.array([sublist[5] for sublist in sensors_presio_2]),
      'P2 sensor pressió 7': np.array([sublist[6] for sublist in sensors_presio_2]),
      'P2 sensor pressió 8': np.array([sublist[7] for sublist in sensors_presio_2]),
      'P2 sensor pressió 9': np.array([sublist[8] for sublist in sensors_presio_2]),
      'P2 sensor pressió 10': np.array([sublist[9] for sublist in sensors_presio_2]),
      'P2 sensor pressió 11': np.array([sublist[10] for sublist in sensors_presio_2]),
      'P2 sensor pressió 12': np.array([sublist[11] for sublist in sensors_presio_2]),
      'P2 sensor pressió 13': np.array([sublist[12] for sublist in sensors_presio_2]),
      'P2 sensor pressió 14': np.array([sublist[13] for sublist in sensors_presio_2]),
      'P2 Temps Sistema': np.array(temps_sistema_2),
      'P2 Calibració': np.array(calibracio_2)
})
    df['P1 Temps Sistema'] = [datetime.datetime.fromtimestamp(unix_time) for unix_time in df['P1 Temps Sistema']]
    df['P2 Temps Sistema'] = [datetime.datetime.fromtimestamp(unix_time) for unix_time in df['P2 Temps Sistema']]

  except FileNotFoundError:
    print("L'usuari o la data no son correctes")
    return

  return df

# %%
def create_df_final(ini,fin):
  df_final = pd.DataFrame()
  with open('/dates_estudiar.txt', 'r') as doc:
    lines = doc.readlines()
    analitzats = []
    i=ini
    for line in lines[ini:fin]:
      i+=1
      l_data = line[0:10]
      if (i<454):
        l_usuari = line[11:13]
      else:
        l_usuari = line[11:14]
      if int(l_usuari) in u_falls and int(l_usuari) not in analitzats:
        print("L'usuari " + l_usuari + " té caigudes")
        ruta_archivo = 'data/'+l_usuari+'/Falls.txt'
        # Leer el archivo y convertir las fechas a objetos datetime
        with open(ruta_archivo, 'r') as file:
          fechas = [datetime.datetime.strptime(line.strip(), "%m/%d/%Y %H:%M:%S") for line in file]
        # Crear el DataFrame con las fechas
        df_fechas = pd.DataFrame({'Fecha': fechas})
        analitzats.append(int(l_usuari))
      print("Creant df de l'usuari "+l_usuari+" per la data " + l_data + "   Linia "+str(i)+"/"+str(fin))
      df = create_df(l_usuari,l_data)
      if int(l_usuari) in u_falls:
        df['Fall'] = ((df['P1 Temps Sistema'].isin(df_fechas['Fecha'])) | (df['P2 Temps Sistema'].isin(df_fechas['Fecha']))).astype(int)
      else:
        df['Fall'] = 0
      df_final = pd.concat([df_final,df])
  return df_final

# %% [markdown]
# ## Creació dataframes

# %%
df1 = create_df_final(0,100)
df1.to_csv("df1.csv")
# Out:
# L'usuari 17 té caigudes
# Creant df de l'usuari 17 per la data 11-09-2014   Linia 1/100
# Creant df de l'usuari 17 per la data 18-09-2014   Linia 2/100
# Creant df de l'usuari 17 per la data 15-10-2014   Linia 3/100
# Creant df de l'usuari 17 per la data 24-10-2014   Linia 4/100
# Creant df de l'usuari 17 per la data 29-10-2014   Linia 5/100
# Creant df de l'usuari 17 per la data 12-11-2014   Linia 6/100
# Creant df de l'usuari 17 per la data 13-11-2014   Linia 7/100
# Creant df de l'usuari 17 per la data 09-12-2014   Linia 8/100
# Creant df de l'usuari 17 per la data 04-12-2014   Linia 9/100
# Creant df de l'usuari 17 per la data 03-12-2014   Linia 10/100
# Creant df de l'usuari 17 per la data 12-12-2014   Linia 11/100
# Creant df de l'usuari 17 per la data 17-12-2014   Linia 12/100
# Creant df de l'usuari 17 per la data 18-01-2015   Linia 13/100
# Creant df de l'usuari 17 per la data 30-01-2015   Linia 14/100
# Creant df de l'usuari 17 per la data 02-02-2015   Linia 15/100
# Creant df de l'usuari 17 per la data 04-02-2015   Linia 16/100
# Creant df de l'usuari 17 per la data 25-02-2015   Linia 17/100
# Creant df de l'usuari 17 per la data 03-03-2015   Linia 18/100
# Creant df de l'usuari 17 per la data 22-04-2015   Linia 19/100
# Creant df de l'usuari 17 per la data 17-04-2015   Linia 20/100
# Creant df de l'usuari 17 per la data 24-04-2015   Linia 21/100
# Creant df de l'usuari 17 per la data 04-05-2015   Linia 22/100
# Creant df de l'usuari 17 per la data 05-05-2015   Linia 23/100
# Creant df de l'usuari 17 per la data 09-05-2015   Linia 24/100
# Creant df de l'usuari 17 per la data 27-07-2015   Linia 25/100
# Creant df de l'usuari 17 per la data 01-04-2015   Linia 26/100
# L'usuari 20 té caigudes
# Creant df de l'usuari 20 per la data 16-09-2014   Linia 27/100
# Creant df de l'usuari 20 per la data 18-09-2014   Linia 28/100
# Creant df de l'usuari 20 per la data 19-09-2014   Linia 29/100
# Creant df de l'usuari 20 per la data 22-09-2014   Linia 30/100
# Creant df de l'usuari 20 per la data 23-09-2014   Linia 31/100
# Creant df de l'usuari 20 per la data 24-09-2014   Linia 32/100
# Creant df de l'usuari 20 per la data 01-10-2014   Linia 33/100
# Creant df de l'usuari 20 per la data 03-10-2014   Linia 34/100
# Creant df de l'usuari 20 per la data 06-10-2014   Linia 35/100
# Creant df de l'usuari 20 per la data 07-10-2014   Linia 36/100
# Creant df de l'usuari 20 per la data 08-10-2014   Linia 37/100
# Creant df de l'usuari 20 per la data 09-10-2014   Linia 38/100
# Creant df de l'usuari 20 per la data 14-10-2014   Linia 39/100
# Creant df de l'usuari 20 per la data 22-10-2014   Linia 40/100
# Creant df de l'usuari 20 per la data 23-10-2014   Linia 41/100
# Creant df de l'usuari 20 per la data 31-10-2014   Linia 42/100
# Creant df de l'usuari 20 per la data 03-11-2014   Linia 43/100
# Creant df de l'usuari 20 per la data 06-11-2014   Linia 44/100
# Creant df de l'usuari 20 per la data 04-11-2014   Linia 45/100
# Creant df de l'usuari 20 per la data 05-11-2014   Linia 46/100
# Creant df de l'usuari 20 per la data 17-11-2014   Linia 47/100
# Creant df de l'usuari 20 per la data 19-11-2014   Linia 48/100
# Creant df de l'usuari 20 per la data 21-11-2014   Linia 49/100
# Creant df de l'usuari 20 per la data 24-11-2014   Linia 50/100
# Creant df de l'usuari 20 per la data 25-11-2014   Linia 51/100
# Creant df de l'usuari 20 per la data 01-12-2014   Linia 52/100
# Creant df de l'usuari 20 per la data 02-12-2014   Linia 53/100
# Creant df de l'usuari 20 per la data 03-12-2014   Linia 54/100
# Creant df de l'usuari 20 per la data 04-12-2014   Linia 55/100
# Creant df de l'usuari 20 per la data 09-12-2014   Linia 56/100
# Creant df de l'usuari 20 per la data 12-12-2014   Linia 57/100
# Creant df de l'usuari 20 per la data 08-01-2015   Linia 58/100
# Creant df de l'usuari 20 per la data 06-02-2015   Linia 59/100
# Creant df de l'usuari 20 per la data 17-12-2014   Linia 60/100
# Creant df de l'usuari 20 per la data 15-12-2014   Linia 61/100
# Creant df de l'usuari 20 per la data 15-12-2014   Linia 62/100
# Creant df de l'usuari 20 per la data 15-12-2014   Linia 63/100
# Creant df de l'usuari 20 per la data 14-03-2015   Linia 64/100
# Creant df de l'usuari 20 per la data 13-03-2015   Linia 65/100
# Creant df de l'usuari 20 per la data 03-03-2015   Linia 66/100
# Creant df de l'usuari 20 per la data 16-03-2015   Linia 67/100
# Creant df de l'usuari 20 per la data 06-03-2015   Linia 68/100
# Creant df de l'usuari 20 per la data 17-03-2015   Linia 69/100
# Creant df de l'usuari 20 per la data 11-03-2015   Linia 70/100
# Creant df de l'usuari 20 per la data 12-03-2015   Linia 71/100
# Creant df de l'usuari 20 per la data 27-02-2015   Linia 72/100
# Creant df de l'usuari 20 per la data 18-03-2015   Linia 73/100
# Creant df de l'usuari 20 per la data 30-03-2015   Linia 74/100
# Creant df de l'usuari 20 per la data 31-03-2015   Linia 75/100
# Creant df de l'usuari 20 per la data 07-04-2015   Linia 76/100
# Creant df de l'usuari 20 per la data 08-04-2015   Linia 77/100
# Creant df de l'usuari 20 per la data 01-07-2015   Linia 78/100
# Creant df de l'usuari 20 per la data 06-09-2016   Linia 79/100
# Creant df de l'usuari 20 per la data 07-09-2016   Linia 80/100
# Creant df de l'usuari 20 per la data 18-01-2017   Linia 81/100
# Creant df de l'usuari 20 per la data 19-01-2017   Linia 82/100
# Creant df de l'usuari 20 per la data 22-09-2016   Linia 83/100
# Creant df de l'usuari 20 per la data 14-10-2016   Linia 84/100
# Creant df de l'usuari 33 per la data 09-10-2014   Linia 85/100
# Creant df de l'usuari 33 per la data 10-10-2014   Linia 86/100
# Creant df de l'usuari 33 per la data 11-10-2014   Linia 87/100
# Creant df de l'usuari 33 per la data 12-10-2014   Linia 88/100
# Creant df de l'usuari 33 per la data 14-10-2014   Linia 89/100
# Creant df de l'usuari 33 per la data 15-10-2014   Linia 90/100
# Creant df de l'usuari 33 per la data 02-10-2014   Linia 91/100
# Creant df de l'usuari 33 per la data 20-10-2014   Linia 92/100
# Creant df de l'usuari 33 per la data 21-10-2014   Linia 93/100
# Creant df de l'usuari 33 per la data 16-10-2014   Linia 94/100
# Creant df de l'usuari 34 per la data 11-09-2014   Linia 95/100
# Creant df de l'usuari 34 per la data 13-09-2014   Linia 96/100
# Creant df de l'usuari 34 per la data 14-09-2014   Linia 97/100
# Creant df de l'usuari 34 per la data 12-09-2014   Linia 98/100
# Creant df de l'usuari 34 per la data 17-09-2014   Linia 99/100
# Creant df de l'usuari 34 per la data 15-10-2014   Linia 100/100

# %%
df1.memory_usage().sum()
# Out:
# 6710784080

# %%
df2 = create_df_final(100,200)
df2.memory_usage().sum()
df2.to_csv("df2.csv")
# Out:
# Creant df de l'usuari 34 per la data 17-10-2014   Linia 1/100
# Creant df de l'usuari 34 per la data 16-10-2014   Linia 2/100
# Creant df de l'usuari 34 per la data 06-11-2014   Linia 3/100
# Creant df de l'usuari 34 per la data 18-11-2014   Linia 4/100
# Creant df de l'usuari 36 per la data 21-09-2014   Linia 5/100
# Creant df de l'usuari 36 per la data 23-09-2014   Linia 6/100
# Creant df de l'usuari 36 per la data 18-09-2014   Linia 7/100
# Creant df de l'usuari 36 per la data 20-09-2014   Linia 8/100
# Creant df de l'usuari 36 per la data 19-09-2014   Linia 9/100
# Creant df de l'usuari 36 per la data 24-09-2014   Linia 10/100
# Creant df de l'usuari 40 per la data 25-09-2014   Linia 11/100
# Creant df de l'usuari 40 per la data 26-09-2014   Linia 12/100
# Creant df de l'usuari 40 per la data 24-09-2014   Linia 13/100
# Creant df de l'usuari 42 per la data 02-10-2014   Linia 14/100
# Creant df de l'usuari 42 per la data 04-10-2014   Linia 15/100
# Creant df de l'usuari 42 per la data 03-10-2014   Linia 16/100
# Creant df de l'usuari 42 per la data 07-11-2014   Linia 17/100
# Creant df de l'usuari 44 per la data 13-10-2014   Linia 18/100
# Creant df de l'usuari 44 per la data 10-10-2014   Linia 19/100
# Creant df de l'usuari 44 per la data 14-10-2014   Linia 20/100
# Creant df de l'usuari 44 per la data 15-10-2014   Linia 21/100
# Creant df de l'usuari 45 per la data 15-10-2014   Linia 22/100
# Creant df de l'usuari 45 per la data 16-10-2014   Linia 23/100
# Creant df de l'usuari 45 per la data 17-10-2014   Linia 24/100
# Creant df de l'usuari 45 per la data 18-10-2014   Linia 25/100
# Creant df de l'usuari 46 per la data 17-10-2014   Linia 26/100
# Creant df de l'usuari 46 per la data 20-10-2014   Linia 27/100
# Creant df de l'usuari 46 per la data 22-10-2014   Linia 28/100
# Creant df de l'usuari 48 per la data 08-11-2015   Linia 29/100
# Creant df de l'usuari 48 per la data 08-11-2021   Linia 30/100
# Creant df de l'usuari 48 per la data 10-11-2014   Linia 31/100
# Creant df de l'usuari 48 per la data 08-11-2014   Linia 32/100
# Creant df de l'usuari 48 per la data 01-11-2014   Linia 33/100
# Creant df de l'usuari 48 per la data 06-11-2014   Linia 34/100
# Creant df de l'usuari 48 per la data 05-11-2014   Linia 35/100
# Creant df de l'usuari 48 per la data 31-10-2014   Linia 36/100
# Creant df de l'usuari 48 per la data 09-11-2014   Linia 37/100
# Creant df de l'usuari 48 per la data 07-11-2014   Linia 38/100
# Creant df de l'usuari 48 per la data 13-11-2014   Linia 39/100
# Creant df de l'usuari 48 per la data 14-11-2014   Linia 40/100
# Creant df de l'usuari 48 per la data 15-11-2014   Linia 41/100
# Creant df de l'usuari 49 per la data 22-10-2014   Linia 42/100
# Creant df de l'usuari 49 per la data 17-10-2014   Linia 43/100
# Creant df de l'usuari 49 per la data 23-10-2014   Linia 44/100
# Creant df de l'usuari 49 per la data 24-10-2014   Linia 45/100
# Creant df de l'usuari 49 per la data 25-10-2014   Linia 46/100
# Creant df de l'usuari 50 per la data 23-10-2014   Linia 47/100
# Creant df de l'usuari 50 per la data 25-10-2014   Linia 48/100
# Creant df de l'usuari 50 per la data 27-10-2014   Linia 49/100
# Creant df de l'usuari 50 per la data 26-10-2014   Linia 50/100
# Creant df de l'usuari 50 per la data 29-10-2014   Linia 51/100
# Creant df de l'usuari 50 per la data 30-10-2014   Linia 52/100
# L'usuari 51 té caigudes
# Creant df de l'usuari 51 per la data 30-10-2014   Linia 53/100
# Creant df de l'usuari 51 per la data 28-10-2014   Linia 54/100
# Creant df de l'usuari 51 per la data 27-10-2014   Linia 55/100
# Creant df de l'usuari 51 per la data 15-12-2014   Linia 56/100
# Creant df de l'usuari 51 per la data 07-12-2014   Linia 57/100
# Creant df de l'usuari 51 per la data 16-12-2014   Linia 58/100
# Creant df de l'usuari 51 per la data 17-12-2014   Linia 59/100
# Creant df de l'usuari 51 per la data 18-12-2014   Linia 60/100
# Creant df de l'usuari 51 per la data 19-12-2014   Linia 61/100
# Creant df de l'usuari 51 per la data 20-12-2014   Linia 62/100
# Creant df de l'usuari 51 per la data 21-12-2014   Linia 63/100
# Creant df de l'usuari 51 per la data 22-12-2014   Linia 64/100
# Creant df de l'usuari 51 per la data 23-12-2014   Linia 65/100
# Creant df de l'usuari 51 per la data 25-12-2014   Linia 66/100
# Creant df de l'usuari 51 per la data 26-12-2014   Linia 67/100
# Creant df de l'usuari 51 per la data 27-12-2014   Linia 68/100
# Creant df de l'usuari 51 per la data 28-12-2014   Linia 69/100
# Creant df de l'usuari 51 per la data 29-12-2014   Linia 70/100
# Creant df de l'usuari 51 per la data 30-12-2014   Linia 71/100
# Creant df de l'usuari 51 per la data 13-01-2015   Linia 72/100
# Creant df de l'usuari 51 per la data 02-01-1970   Linia 73/100
# Creant df de l'usuari 54 per la data 09-11-2014   Linia 74/100
# Creant df de l'usuari 54 per la data 12-11-2014   Linia 75/100
# Creant df de l'usuari 54 per la data 14-11-2014   Linia 76/100
# Creant df de l'usuari 54 per la data 15-11-2014   Linia 77/100
# Creant df de l'usuari 54 per la data 18-11-2014   Linia 78/100
# Creant df de l'usuari 54 per la data 19-11-2014   Linia 79/100
# Creant df de l'usuari 54 per la data 23-11-2014   Linia 80/100
# Creant df de l'usuari 54 per la data 24-11-2014   Linia 81/100
# Creant df de l'usuari 54 per la data 28-11-2014   Linia 82/100
# Creant df de l'usuari 55 per la data 09-11-2014   Linia 83/100
# Creant df de l'usuari 56 per la data 05-12-2014   Linia 84/100
# Creant df de l'usuari 56 per la data 11-12-2014   Linia 85/100
# Creant df de l'usuari 56 per la data 10-12-2014   Linia 86/100
# Creant df de l'usuari 56 per la data 06-12-2014   Linia 87/100
# L'usuari 59 té caigudes
# Creant df de l'usuari 59 per la data 19-11-2014   Linia 88/100
# Creant df de l'usuari 59 per la data 22-11-2014   Linia 89/100
# Creant df de l'usuari 59 per la data 21-11-2014   Linia 90/100
# Creant df de l'usuari 59 per la data 20-11-2014   Linia 91/100
# Creant df de l'usuari 59 per la data 01-12-2014   Linia 92/100
# Creant df de l'usuari 59 per la data 28-11-2014   Linia 93/100
# Creant df de l'usuari 59 per la data 02-12-2014   Linia 94/100
# Creant df de l'usuari 59 per la data 30-11-2014   Linia 95/100
# Creant df de l'usuari 59 per la data 27-11-2014   Linia 96/100
# Creant df de l'usuari 59 per la data 29-11-2014   Linia 97/100
# Creant df de l'usuari 59 per la data 23-11-2014   Linia 98/100
# Creant df de l'usuari 59 per la data 11-02-2015   Linia 99/100
# Creant df de l'usuari 59 per la data 16-02-2015   Linia 100/100

# %%
df3 = create_df_final(200,300)
print(df3.memory_usage().sum())
df3.to_csv("df3.csv")
# Out:
# L'usuari 59 té caigudes
# Creant df de l'usuari 59 per la data 18-02-2015   Linia 1/100
# Creant df de l'usuari 59 per la data 19-02-2015   Linia 2/100
# Creant df de l'usuari 59 per la data 25-02-2015   Linia 3/100
# Creant df de l'usuari 59 per la data 26-02-2015   Linia 4/100
# Creant df de l'usuari 59 per la data 04-05-2015   Linia 5/100
# Creant df de l'usuari 59 per la data 05-05-2015   Linia 6/100
# Creant df de l'usuari 59 per la data 07-05-2015   Linia 7/100
# Creant df de l'usuari 59 per la data 11-05-2015   Linia 8/100
# Creant df de l'usuari 59 per la data 28-07-2015   Linia 9/100
# Creant df de l'usuari 59 per la data 29-07-2015   Linia 10/100
# Creant df de l'usuari 59 per la data 13-11-2015   Linia 11/100
# Creant df de l'usuari 59 per la data 17-11-2015   Linia 12/100
# Creant df de l'usuari 59 per la data 26-11-2015   Linia 13/100
# Creant df de l'usuari 59 per la data 03-12-2015   Linia 14/100
# Creant df de l'usuari 59 per la data 04-12-2015   Linia 15/100
# Creant df de l'usuari 59 per la data 09-12-2015   Linia 16/100
# Creant df de l'usuari 59 per la data 11-12-2015   Linia 17/100
# Creant df de l'usuari 59 per la data 19-11-2015   Linia 18/100
# Creant df de l'usuari 59 per la data 20-11-2015   Linia 19/100
# Creant df de l'usuari 59 per la data 27-11-2015   Linia 20/100
# Creant df de l'usuari 60 per la data 25-11-2014   Linia 21/100
# Creant df de l'usuari 60 per la data 27-11-2014   Linia 22/100
# Creant df de l'usuari 60 per la data 20-11-2014   Linia 23/100
# Creant df de l'usuari 60 per la data 24-11-2014   Linia 24/100
# Creant df de l'usuari 60 per la data 23-11-2014   Linia 25/100
# Creant df de l'usuari 60 per la data 22-11-2014   Linia 26/100
# Creant df de l'usuari 60 per la data 21-11-2014   Linia 27/100
# Creant df de l'usuari 60 per la data 19-11-2014   Linia 28/100
# L'usuari 61 té caigudes
# Creant df de l'usuari 61 per la data 25-11-2014   Linia 29/100
# Creant df de l'usuari 61 per la data 26-11-2014   Linia 30/100
# Creant df de l'usuari 61 per la data 27-11-2014   Linia 31/100
# Creant df de l'usuari 61 per la data 23-11-2014   Linia 32/100
# Creant df de l'usuari 61 per la data 22-11-2014   Linia 33/100
# Creant df de l'usuari 61 per la data 19-11-2014   Linia 34/100
# Creant df de l'usuari 61 per la data 21-11-2014   Linia 35/100
# Creant df de l'usuari 61 per la data 20-11-2014   Linia 36/100
# L'usuari 62 té caigudes
# Creant df de l'usuari 62 per la data 24-11-2014   Linia 37/100
# Creant df de l'usuari 62 per la data 26-11-2014   Linia 38/100
# Creant df de l'usuari 62 per la data 25-11-2014   Linia 39/100
# Creant df de l'usuari 62 per la data 27-11-2014   Linia 40/100
# Creant df de l'usuari 62 per la data 30-11-2014   Linia 41/100
# Creant df de l'usuari 62 per la data 29-11-2014   Linia 42/100
# Creant df de l'usuari 62 per la data 01-12-2014   Linia 43/100
# Creant df de l'usuari 62 per la data 03-12-2014   Linia 44/100
# Creant df de l'usuari 62 per la data 04-12-2014   Linia 45/100
# Creant df de l'usuari 62 per la data 26-02-2015   Linia 46/100
# L'usuari 63 té caigudes
# Creant df de l'usuari 63 per la data 24-11-2014   Linia 47/100
# Creant df de l'usuari 63 per la data 02-12-2014   Linia 48/100
# Creant df de l'usuari 63 per la data 04-12-2014   Linia 49/100
# Creant df de l'usuari 63 per la data 03-12-2014   Linia 50/100
# L'usuari 64 té caigudes
# Creant df de l'usuari 64 per la data 24-11-2014   Linia 51/100
# Creant df de l'usuari 64 per la data 25-11-2014   Linia 52/100
# Creant df de l'usuari 64 per la data 03-12-2014   Linia 53/100
# Creant df de l'usuari 64 per la data 02-12-2014   Linia 54/100
# Creant df de l'usuari 64 per la data 04-12-2014   Linia 55/100
# Creant df de l'usuari 64 per la data 06-12-2014   Linia 56/100
# Creant df de l'usuari 64 per la data 24-02-2015   Linia 57/100
# Creant df de l'usuari 64 per la data 26-02-2015   Linia 58/100
# Creant df de l'usuari 64 per la data 20-02-2015   Linia 59/100
# Creant df de l'usuari 64 per la data 07-12-2014   Linia 60/100
# Creant df de l'usuari 66 per la data 27-11-2014   Linia 61/100
# Creant df de l'usuari 66 per la data 28-11-2014   Linia 62/100
# Creant df de l'usuari 66 per la data 21-11-2014   Linia 63/100
# Creant df de l'usuari 66 per la data 25-11-2014   Linia 64/100
# Creant df de l'usuari 66 per la data 29-11-2014   Linia 65/100
# Creant df de l'usuari 66 per la data 09-12-2014   Linia 66/100
# Creant df de l'usuari 66 per la data 22-11-2014   Linia 67/100
# Creant df de l'usuari 66 per la data 05-12-2014   Linia 68/100
# Creant df de l'usuari 66 per la data 04-12-2014   Linia 69/100
# Creant df de l'usuari 66 per la data 30-11-2014   Linia 70/100
# Creant df de l'usuari 66 per la data 03-12-2014   Linia 71/100
# Creant df de l'usuari 66 per la data 02-12-2014   Linia 72/100
# Creant df de l'usuari 66 per la data 01-12-2014   Linia 73/100
# Creant df de l'usuari 67 per la data 05-12-2014   Linia 74/100
# Creant df de l'usuari 67 per la data 30-11-2014   Linia 75/100
# Creant df de l'usuari 67 per la data 20-11-2014   Linia 76/100
# Creant df de l'usuari 67 per la data 27-11-2014   Linia 77/100
# Creant df de l'usuari 67 per la data 28-11-2014   Linia 78/100
# Creant df de l'usuari 69 per la data 09-12-2014   Linia 79/100
# Creant df de l'usuari 69 per la data 20-12-2014   Linia 80/100
# Creant df de l'usuari 69 per la data 12-12-2014   Linia 81/100
# Creant df de l'usuari 69 per la data 13-12-2014   Linia 82/100
# Creant df de l'usuari 69 per la data 16-12-2014   Linia 83/100
# Creant df de l'usuari 69 per la data 17-12-2014   Linia 84/100
# Creant df de l'usuari 69 per la data 15-12-2014   Linia 85/100
# Creant df de l'usuari 69 per la data 08-12-2014   Linia 86/100
# Creant df de l'usuari 69 per la data 18-12-2014   Linia 87/100
# Creant df de l'usuari 69 per la data 19-12-2014   Linia 88/100
# Creant df de l'usuari 70 per la data 07-12-2014   Linia 89/100
# Creant df de l'usuari 73 per la data 08-12-2014   Linia 90/100
# Creant df de l'usuari 74 per la data 08-12-2014   Linia 91/100
# Creant df de l'usuari 75 per la data 08-12-2014   Linia 92/100
# Creant df de l'usuari 76 per la data 08-12-2014   Linia 93/100
# L'usuari 78 té caigudes
# Creant df de l'usuari 78 per la data 15-12-2014   Linia 94/100
# Creant df de l'usuari 78 per la data 16-12-2014   Linia 95/100
# Creant df de l'usuari 78 per la data 17-12-2014   Linia 96/100
# Creant df de l'usuari 78 per la data 13-12-2014   Linia 97/100
# Creant df de l'usuari 78 per la data 14-12-2014   Linia 98/100
# Creant df de l'usuari 78 per la data 10-12-2014   Linia 99/100
# Creant df de l'usuari 78 per la data 11-12-2014   Linia 100/100
# 6220973880

# %%
df4 = create_df_final(300,400)
print(df4.memory_usage().sum())
df4.to_csv("df4.csv")
# Out:
# L'usuari 78 té caigudes
# Creant df de l'usuari 78 per la data 05-12-2014   Linia 1/100
# Creant df de l'usuari 78 per la data 24-11-2014   Linia 2/100
# Creant df de l'usuari 78 per la data 21-11-2014   Linia 3/100
# Creant df de l'usuari 78 per la data 27-11-2014   Linia 4/100
# Creant df de l'usuari 78 per la data 19-11-2014   Linia 5/100
# Creant df de l'usuari 78 per la data 28-11-2014   Linia 6/100
# Creant df de l'usuari 78 per la data 06-12-2014   Linia 7/100
# Creant df de l'usuari 78 per la data 09-12-2014   Linia 8/100
# Creant df de l'usuari 78 per la data 22-11-2014   Linia 9/100
# Creant df de l'usuari 78 per la data 23-11-2014   Linia 10/100
# Creant df de l'usuari 78 per la data 12-12-2014   Linia 11/100
# Creant df de l'usuari 78 per la data 03-02-2015   Linia 12/100
# Creant df de l'usuari 78 per la data 11-02-2015   Linia 13/100
# Creant df de l'usuari 79 per la data 17-12-2014   Linia 14/100
# Creant df de l'usuari 79 per la data 04-02-2015   Linia 15/100
# Creant df de l'usuari 79 per la data 12-12-2014   Linia 16/100
# Creant df de l'usuari 79 per la data 15-12-2014   Linia 17/100
# Creant df de l'usuari 79 per la data 10-12-2014   Linia 18/100
# Creant df de l'usuari 79 per la data 16-12-2014   Linia 19/100
# Creant df de l'usuari 79 per la data 11-12-2014   Linia 20/100
# Creant df de l'usuari 80 per la data 01-12-2014   Linia 21/100
# Creant df de l'usuari 80 per la data 10-12-2014   Linia 22/100
# Creant df de l'usuari 80 per la data 12-12-2014   Linia 23/100
# Creant df de l'usuari 80 per la data 13-12-2014   Linia 24/100
# Creant df de l'usuari 80 per la data 11-12-2014   Linia 25/100
# L'usuari 81 té caigudes
# Creant df de l'usuari 81 per la data 17-12-2014   Linia 26/100
# Creant df de l'usuari 81 per la data 05-02-2015   Linia 27/100
# Creant df de l'usuari 81 per la data 09-02-2015   Linia 28/100
# Creant df de l'usuari 81 per la data 12-02-2015   Linia 29/100
# Creant df de l'usuari 81 per la data 11-02-2015   Linia 30/100
# Creant df de l'usuari 81 per la data 08-02-2015   Linia 31/100
# Creant df de l'usuari 81 per la data 07-02-2015   Linia 32/100
# Creant df de l'usuari 81 per la data 06-02-2015   Linia 33/100
# Creant df de l'usuari 81 per la data 10-02-2015   Linia 34/100
# Creant df de l'usuari 81 per la data 25-02-2015   Linia 35/100
# Creant df de l'usuari 81 per la data 15-12-2014   Linia 36/100
# Creant df de l'usuari 81 per la data 09-12-2014   Linia 37/100
# Creant df de l'usuari 81 per la data 13-12-2014   Linia 38/100
# Creant df de l'usuari 81 per la data 10-12-2014   Linia 39/100
# Creant df de l'usuari 81 per la data 11-12-2014   Linia 40/100
# Creant df de l'usuari 81 per la data 16-12-2014   Linia 41/100
# Creant df de l'usuari 81 per la data 12-12-2014   Linia 42/100
# Creant df de l'usuari 82 per la data 11-12-2014   Linia 43/100
# L'usuari 83 té caigudes
# Creant df de l'usuari 83 per la data 31-12-2014   Linia 44/100
# Creant df de l'usuari 83 per la data 29-12-2014   Linia 45/100
# Creant df de l'usuari 83 per la data 25-12-2014   Linia 46/100
# Creant df de l'usuari 83 per la data 24-12-2014   Linia 47/100
# Creant df de l'usuari 83 per la data 17-12-2014   Linia 48/100
# Creant df de l'usuari 83 per la data 16-12-2014   Linia 49/100
# Creant df de l'usuari 83 per la data 14-12-2014   Linia 50/100
# Creant df de l'usuari 83 per la data 15-12-2014   Linia 51/100
# Creant df de l'usuari 84 per la data 14-12-2014   Linia 52/100
# Creant df de l'usuari 84 per la data 21-12-2014   Linia 53/100
# Creant df de l'usuari 84 per la data 23-12-2014   Linia 54/100
# Creant df de l'usuari 84 per la data 31-12-2014   Linia 55/100
# Creant df de l'usuari 84 per la data 30-12-2014   Linia 56/100
# Creant df de l'usuari 84 per la data 22-12-2014   Linia 57/100
# Creant df de l'usuari 84 per la data 01-01-2015   Linia 58/100
# Creant df de l'usuari 84 per la data 29-12-2014   Linia 59/100
# L'usuari 85 té caigudes
# Creant df de l'usuari 85 per la data 04-12-2014   Linia 60/100
# Creant df de l'usuari 85 per la data 03-12-2014   Linia 61/100
# Creant df de l'usuari 85 per la data 23-12-2014   Linia 62/100
# Creant df de l'usuari 85 per la data 22-12-2014   Linia 63/100
# Creant df de l'usuari 85 per la data 26-12-2014   Linia 64/100
# Creant df de l'usuari 85 per la data 27-12-2014   Linia 65/100
# Creant df de l'usuari 85 per la data 25-12-2014   Linia 66/100
# Creant df de l'usuari 85 per la data 28-12-2014   Linia 67/100
# Creant df de l'usuari 85 per la data 29-12-2014   Linia 68/100
# Creant df de l'usuari 85 per la data 30-12-2014   Linia 69/100
# Creant df de l'usuari 85 per la data 31-12-2014   Linia 70/100
# Creant df de l'usuari 85 per la data 02-01-2015   Linia 71/100
# Creant df de l'usuari 85 per la data 08-01-2015   Linia 72/100
# Creant df de l'usuari 85 per la data 18-01-2015   Linia 73/100
# Creant df de l'usuari 85 per la data 20-02-2015   Linia 74/100
# Creant df de l'usuari 85 per la data 15-02-2015   Linia 75/100
# Creant df de l'usuari 85 per la data 23-01-2015   Linia 76/100
# Creant df de l'usuari 85 per la data 24-12-2014   Linia 77/100
# L'usuari 88 té caigudes
# Creant df de l'usuari 88 per la data 23-12-2014   Linia 78/100
# Creant df de l'usuari 88 per la data 25-12-2014   Linia 79/100
# Creant df de l'usuari 88 per la data 27-12-2014   Linia 80/100
# Creant df de l'usuari 88 per la data 26-12-2014   Linia 81/100
# Creant df de l'usuari 88 per la data 24-12-2014   Linia 82/100
# Creant df de l'usuari 88 per la data 11-12-2014   Linia 83/100
# L'usuari 89 té caigudes
# Creant df de l'usuari 89 per la data 24-12-2014   Linia 84/100
# Creant df de l'usuari 89 per la data 28-12-2014   Linia 85/100
# Creant df de l'usuari 89 per la data 29-12-2014   Linia 86/100
# Creant df de l'usuari 89 per la data 27-12-2014   Linia 87/100
# Creant df de l'usuari 89 per la data 16-12-2014   Linia 88/100
# Creant df de l'usuari 89 per la data 14-12-2014   Linia 89/100
# Creant df de l'usuari 89 per la data 15-12-2014   Linia 90/100
# Creant df de l'usuari 89 per la data 17-12-2014   Linia 91/100
# L'usuari 90 té caigudes
# Creant df de l'usuari 90 per la data 01-01-2015   Linia 92/100
# Creant df de l'usuari 90 per la data 02-01-2015   Linia 93/100
# Creant df de l'usuari 90 per la data 04-01-2015   Linia 94/100
# Creant df de l'usuari 90 per la data 29-12-2014   Linia 95/100
# Creant df de l'usuari 90 per la data 27-12-2014   Linia 96/100
# Creant df de l'usuari 90 per la data 13-01-2015   Linia 97/100
# L'usuari 91 té caigudes
# Creant df de l'usuari 91 per la data 21-01-2015   Linia 98/100
# Creant df de l'usuari 91 per la data 28-01-2015   Linia 99/100
# Creant df de l'usuari 91 per la data 26-01-2015   Linia 100/100
# 14804555480

# %%
df5 = create_df_final(400,492)
print(df5.memory_usage().sum())
df5.to_csv("df5.csv")
# Out:
# L'usuari 91 té caigudes
# Creant df de l'usuari 91 per la data 25-01-2015   Linia 401/492
# Creant df de l'usuari 91 per la data 23-01-2015   Linia 402/492
# Creant df de l'usuari 91 per la data 24-01-2015   Linia 403/492
# Creant df de l'usuari 91 per la data 01-02-2015   Linia 404/492
# Creant df de l'usuari 91 per la data 02-02-2015   Linia 405/492
# Creant df de l'usuari 91 per la data 31-01-2015   Linia 406/492
# Creant df de l'usuari 91 per la data 30-01-2015   Linia 407/492
# Creant df de l'usuari 91 per la data 29-01-2015   Linia 408/492
# Creant df de l'usuari 91 per la data 22-01-2015   Linia 409/492
# L'usuari 92 té caigudes
# Creant df de l'usuari 92 per la data 19-01-2015   Linia 410/492
# Creant df de l'usuari 92 per la data 20-01-2015   Linia 411/492
# Creant df de l'usuari 92 per la data 22-01-2015   Linia 412/492
# Creant df de l'usuari 92 per la data 21-01-2015   Linia 413/492
# Creant df de l'usuari 92 per la data 23-01-2015   Linia 414/492
# Creant df de l'usuari 92 per la data 24-01-2015   Linia 415/492
# Creant df de l'usuari 92 per la data 26-01-2015   Linia 416/492
# Creant df de l'usuari 92 per la data 27-01-2015   Linia 417/492
# Creant df de l'usuari 92 per la data 28-01-2015   Linia 418/492
# Creant df de l'usuari 92 per la data 29-01-2015   Linia 419/492
# Creant df de l'usuari 92 per la data 30-01-2015   Linia 420/492
# Creant df de l'usuari 92 per la data 01-02-2015   Linia 421/492
# Creant df de l'usuari 92 per la data 31-01-2015   Linia 422/492
# Creant df de l'usuari 92 per la data 02-02-2015   Linia 423/492
# Creant df de l'usuari 92 per la data 24-02-2015   Linia 424/492
# Creant df de l'usuari 92 per la data 14-02-2015   Linia 425/492
# Creant df de l'usuari 95 per la data 17-01-2015   Linia 426/492
# Creant df de l'usuari 95 per la data 15-01-2015   Linia 427/492
# Creant df de l'usuari 95 per la data 16-01-2015   Linia 428/492
# Creant df de l'usuari 95 per la data 23-01-2015   Linia 429/492
# Creant df de l'usuari 95 per la data 24-01-2015   Linia 430/492
# Creant df de l'usuari 95 per la data 31-01-2015   Linia 431/492
# Creant df de l'usuari 95 per la data 27-02-2015   Linia 432/492
# Creant df de l'usuari 95 per la data 13-02-2015   Linia 433/492
# Creant df de l'usuari 95 per la data 09-02-2015   Linia 434/492
# Creant df de l'usuari 95 per la data 10-02-2015   Linia 435/492
# Creant df de l'usuari 96 per la data 24-01-2015   Linia 436/492
# Creant df de l'usuari 96 per la data 01-02-2015   Linia 437/492
# Creant df de l'usuari 96 per la data 03-02-2015   Linia 438/492
# Creant df de l'usuari 96 per la data 08-02-2015   Linia 439/492
# Creant df de l'usuari 96 per la data 26-01-2015   Linia 440/492
# Creant df de l'usuari 96 per la data 28-01-2015   Linia 441/492
# Creant df de l'usuari 96 per la data 07-02-2015   Linia 442/492
# Creant df de l'usuari 96 per la data 29-01-2015   Linia 443/492
# Creant df de l'usuari 96 per la data 27-01-2015   Linia 444/492
# Creant df de l'usuari 96 per la data 18-02-2015   Linia 445/492
# Creant df de l'usuari 96 per la data 19-02-2015   Linia 446/492
# Creant df de l'usuari 96 per la data 26-02-2015   Linia 447/492
# Creant df de l'usuari 96 per la data 20-03-2015   Linia 448/492
# Creant df de l'usuari 96 per la data 21-03-2015   Linia 449/492
# Creant df de l'usuari 98 per la data 31-01-2015   Linia 450/492
# Creant df de l'usuari 98 per la data 30-01-2015   Linia 451/492
# Creant df de l'usuari 98 per la data 02-02-2015   Linia 452/492
# Creant df de l'usuari 98 per la data 29-01-2015   Linia 453/492
# L'usuari 100 té caigudes
# Creant df de l'usuari 100 per la data 08-02-2015   Linia 454/492
# Creant df de l'usuari 100 per la data 03-02-2015   Linia 455/492
# Creant df de l'usuari 100 per la data 17-02-2015   Linia 456/492
# Creant df de l'usuari 100 per la data 19-02-2015   Linia 457/492
# Creant df de l'usuari 100 per la data 24-02-2015   Linia 458/492
# Creant df de l'usuari 100 per la data 26-02-2015   Linia 459/492
# Creant df de l'usuari 100 per la data 16-02-2015   Linia 460/492
# Creant df de l'usuari 101 per la data 16-02-2015   Linia 461/492
# L'usuari 102 té caigudes
# Creant df de l'usuari 102 per la data 05-02-2015   Linia 462/492
# Creant df de l'usuari 102 per la data 09-02-2015   Linia 463/492
# Creant df de l'usuari 102 per la data 12-02-2015   Linia 464/492
# Creant df de l'usuari 102 per la data 11-02-2015   Linia 465/492
# Creant df de l'usuari 102 per la data 08-02-2015   Linia 466/492
# Creant df de l'usuari 102 per la data 10-02-2015   Linia 467/492
# Creant df de l'usuari 102 per la data 06-02-2015   Linia 468/492
# L'usuari 103 té caigudes
# Creant df de l'usuari 103 per la data 11-02-2015   Linia 469/492
# Creant df de l'usuari 103 per la data 09-02-2015   Linia 470/492
# Creant df de l'usuari 103 per la data 26-02-2015   Linia 471/492
# Creant df de l'usuari 103 per la data 10-02-2015   Linia 472/492
# Creant df de l'usuari 103 per la data 24-02-2015   Linia 473/492
# Creant df de l'usuari 103 per la data 15-02-2015   Linia 474/492
# Creant df de l'usuari 103 per la data 25-02-2015   Linia 475/492
# Creant df de l'usuari 103 per la data 23-02-2015   Linia 476/492
# Creant df de l'usuari 103 per la data 19-02-2015   Linia 477/492
# Creant df de l'usuari 103 per la data 20-02-2015   Linia 478/492
# Creant df de l'usuari 103 per la data 22-02-2015   Linia 479/492
# Creant df de l'usuari 103 per la data 21-02-2015   Linia 480/492
# Creant df de l'usuari 103 per la data 18-02-2015   Linia 481/492
# Creant df de l'usuari 103 per la data 04-06-2015   Linia 482/492
# Creant df de l'usuari 103 per la data 08-07-2015   Linia 483/492
# Creant df de l'usuari 103 per la data 15-07-2015   Linia 484/492
# Creant df de l'usuari 103 per la data 14-10-2015   Linia 485/492
# Creant df de l'usuari 103 per la data 23-10-2015   Linia 486/492
# Creant df de l'usuari 103 per la data 28-10-2015   Linia 487/492
# Creant df de l'usuari 103 per la data 24-10-2015   Linia 488/492
# Creant df de l'usuari 103 per la data 25-10-2015   Linia 489/492
# Creant df de l'usuari 103 per la data 24-09-2016   Linia 490/492
# Creant df de l'usuari 103 per la data 22-11-2016   Linia 491/492
# Creant df de l'usuari 103 per la data 29-03-2014   Linia 492/492
# 7339670800

# %% [markdown]
# ## Concatenar dataframes

# %%
df_concatenate = pd.concat([df1,df2,df3,df4,df5])
df_concatenate.to_csv("df_concatenate.csv")
